# %%
# Dependencies
import numpy as np

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# 1. Import the sqlalchemy extract function.
from sqlalchemy import extract
import datetime

# 2. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 
start_date = datetime.date(2017, 6, 1)
end_date = datetime.date(2017, 6, 30)
result = session.query(Measurement.date, Measurement.tobs).filter(Measurement.date >= start_date)\
.filter(Measurement.date <= end_date).all()
result
# Out:
# [('2017-06-01', 79.0),
#  ('2017-06-02', 79.0),
#  ('2017-06-03', 79.0),
#  ('2017-06-04', 79.0),
#  ('2017-06-05', 80.0),
#  ('2017-06-06', 79.0),
#  ('2017-06-07', 79.0),
#  ('2017-06-08', 80.0),
#  ('2017-06-09', 80.0),
#  ('2017-06-10', 77.0),
#  ('2017-06-11', 79.0),
#  ('2017-06-12', 83.0),
#  ('2017-06-13', 80.0),
#  ('2017-06-14', 80.0),
#  ('2017-06-15', 78.0),
#  ('2017-06-16', 79.0),
#  ('2017-06-17', 80.0),
#  ('2017-06-18', 77.0),
#  ('2017-06-19', 80.0),
#  ('2017-06-20', 78.0),
#  ('2017-06-21', 79.0),
#  ('2017-06-22', 80.0),
#  ('2017-06-23', 78.0),
#  ('2017-06-24', 80.0),
#  ('2017-06-25', 80.0),
#  ('2017-06-26', 81.0),
#  ('2017-06-27', 80.0),
#  ('2017-06-28', 79.0),
#  ('2017-06-29', 79.0),
#  ('2017-06-30', 75.0),
#  ('2017-06-01', 76.0),
#  ('2017-06-02', 76.0),
#  ('2017-06-03', 76.0),
#  ('2017-06-04', 78.0),
#  ('2017-06-05', 76.0),
#  ('2017-06-06', 75.0),
#  ('2017-06-07', 75.0),
#  ('2017-06-08', 76.0),
#  ('2017-06-09', 78.0),
#  ('2017-06-10', 75.0),
# ...

# %%
#  3. Convert the June temperatures to a list.
result = [entry[1] for entry in result]
result
# Out:
# [79.0,
#  79.0,
#  79.0,
#  79.0,
#  80.0,
#  79.0,
#  79.0,
#  80.0,
#  80.0,
#  77.0,
#  79.0,
#  83.0,
#  80.0,
#  80.0,
#  78.0,
#  79.0,
#  80.0,
#  77.0,
#  80.0,
#  78.0,
#  79.0,
#  80.0,
#  78.0,
#  80.0,
#  80.0,
#  81.0,
#  80.0,
#  79.0,
#  79.0,
#  75.0,
#  76.0,
#  76.0,
#  76.0,
#  78.0,
#  76.0,
#  75.0,
#  75.0,
#  76.0,
#  78.0,
#  75.0,
#  73.0,
#  76.0,
#  76.0,
#  76.0,
#  77.0,
#  76.0,
#  77.0,
#  72.0,
#  77.0,
#  75.0,
#  82.0,
#  77.0,
#  76.0,
#  74.0,
#  73.0,
#  77.0,
#  77.0,
#  77.0,
#  76.0,
#  74.0,
#  81.0,
#  78.0,
#  80.0,
#  79.0,
#  81.0,
#  80.0,
#  81.0,
#  79.0,
#  81.0,
#  78.0,
#  79.0,
#  79.0,
#  75.0,
#  79.0,
#  78.0,
#  80.0,
#  78.0,
#  77.0,
#  78.0,
#  79.0,
#  76.0,
#  80.0,
#  76.0,
#  81.0,
#  79.0,
#  78.0,
#  80.0,
#  80.0,
#  78.0,
#  80.0,
#  81.0,
#  78.0,
#  77.0,
#  78.0,
#  78.0,
#  77.0,
#  76.0,
#  81.0,
#  76.0,
#  82.0,
#  80.0,
#  80.0,
#  79.0,
#  74.0,
#  79.0,
#  81.0,
#  79.0,
#  81.0,
#  78.0,
#  78.0,
#  78.0,
# ...

# %%
# 4. Create a DataFrame from the list of temperatures for the month of June.
import pandas as pd

df_june = pd.DataFrame(result, columns=['June Temps'])
df_june.head(10)
# Out:
#    June Temps
# 0        79.0
# 1        79.0
# 2        79.0
# 3        79.0
# 4        80.0
# 5        79.0
# 6        79.0
# 7        80.0
# 8        80.0
# 9        77.0

# %%
# 5. Calculate and print out the summary statistics for the June temperature DataFrame.
df_june.describe()
# Out:
#        June Temps
# count  191.000000
# mean    77.219895
# std      2.622538
# min     71.000000
# 25%     75.000000
# 50%     77.000000
# 75%     79.000000
# max     83.000000

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.
start_date = datetime.date(2016, 12, 1)
end_date = datetime.date(2016, 12, 31)

result = session.query(Measurement.date, Measurement.tobs).filter(Measurement.date >= start_date)\
.filter(Measurement.date <= end_date).all()
result[:10]
# Out:
# [('2016-12-01', 75.0),
#  ('2016-12-02', 72.0),
#  ('2016-12-03', 69.0),
#  ('2016-12-04', 71.0),
#  ('2016-12-05', 68.0),
#  ('2016-12-06', 67.0),
#  ('2016-12-07', 69.0),
#  ('2016-12-08', 73.0),
#  ('2016-12-09', 70.0),
#  ('2016-12-10', 70.0)]

# %%
# 7. Convert the December temperatures to a list.
result = [entry[1] for entry in result]
result[:15]
# Out:
# [75.0,
#  72.0,
#  69.0,
#  71.0,
#  68.0,
#  67.0,
#  69.0,
#  73.0,
#  70.0,
#  70.0,
#  70.0,
#  66.0,
#  67.0,
#  70.0,
#  66.0]

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
df_dec = pd.DataFrame(result, columns=['December Temps'])
df_dec.head()
# Out:
#    December Temps
# 0            75.0
# 1            72.0
# 2            69.0
# 3            71.0
# 4            68.0

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
df_dec.describe()
# Out:
#        December Temps
# count      200.000000
# mean        71.130000
# std          3.419292
# min         60.000000
# 25%         69.000000
# 50%         71.000000
# 75%         74.000000
# max         78.000000
